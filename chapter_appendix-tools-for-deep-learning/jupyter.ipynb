# %%
print("harikesh")
# Out:
# harikesh

# %%
import random
import time
def insertion_sort(arr):
  for i in range(1,len(arr)):
      key=arr[i]
  j=i-1
  while j>0 and arr[j]>key:

    arr[j+1]=arr[j]
    j-=1
  arr[j+1]=key

sizes=[5000,6000,7000,8000,9000,10000]
times=[]
for n in sizes:
  data=[random.randint(0,10000) for _ in range(n)]
  start_time=time.time()
  insertion_sort(data)
  end=time.time()
  elapsed=end-start_time
  times.append(elapsed)
  print(f"n ={n},timetaken={elapsed:0.4f}seconds")
# Out:
# n =5000,timetaken=0.0002seconds
# n =6000,timetaken=0.0002seconds
# n =7000,timetaken=0.0003seconds
# n =8000,timetaken=0.0003seconds
# n =9000,timetaken=0.0003seconds
# n =10000,timetaken=0.0003seconds

# %%
print("practical 2 to DAA")
print("Name :- Merger sort")

import random
import time
import matplotlib.pyplot as plt

def merge(left,right):
  merged=[]
  i=j=0

  while i<len(left) and j<len(right):
    if left[i]<right[j]:
      merged.append(left[i])
      i+=1

    if right[j]<left[i]:
      merged.append(right[j])
      j+=1

  merged.extend(left[i:])
  merged.extend(right[j:])
  return merged

def merge_sort(arr):
  if len(arr)<=1:
    return arr
  mid=len(arr)//2
  left=merge_sort(arr[:mid])
  right=merge_sort(arr[mid:])
  return merge(left,right)

  #main logic

  sizes =[ 5000,10000,15000,20000,25000]
  times =[]

  for n in sizes:
    data=[random.randint(1, 100000)for _ in range(n)]
    start_time=time.time()
    merge_sort(data)
    end_time=time.time()
    elapsed=end_time-start_time
    times.append(elapsed)
